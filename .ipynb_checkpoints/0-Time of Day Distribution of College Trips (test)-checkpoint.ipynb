# %%
import os
import pandas as pd

# %%
#google cloud big query libaries
from google.cloud import bigquery
from google.oauth2 import service_account

key_path = r"C:\Users\cday\streetlight-temp-analysis-1aa223143ab5.json"

credentials = service_account.Credentials.from_service_account_file(
    key_path, scopes=["https://www.googleapis.com/auth/cloud-platform"],
)

client = bigquery.Client(credentials=credentials, project=credentials.project_id,)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d6796476f143> in <module>
#       1 #google cloud big query libaries
# ----> 2 from google.cloud import bigquery
#       3 from google.oauth2 import service_account
#       4
#       5 key_path = r"C:\Users\cday\streetlight-temp-analysis-1aa223143ab5.json"
#
# ModuleNotFoundError: No module named 'google.cloud'

# %%
pip show google-cloud-bigquery
# Out:
# Name: google-cloud-bigquery
# Version: 3.3.6
# Summary: Google BigQuery API client library
# Home-page: https://github.com/googleapis/python-bigquery
# Author: Google LLC
# Author-email: googleapis-packages@google.com
# License: Apache 2.0
# Location: c:\users\cday\appdata\local\esri\conda\envs\arcgispro-py3-bigquery\lib\site-packages
# Requires: google-resumable-media, packaging, protobuf, grpcio, pyarrow, requests, proto-plus, google-cloud-bigquery-storage, google-api-core, python-dateutil, google-cloud-core
# Required-by:
# Note: you may need to restart the kernel to use updated packages.
